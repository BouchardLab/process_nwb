# %%
import numpy as np
import matplotlib.pyplot as plt
from imp import reload

import process_nwb
from process_nwb.signal_processing import resample

# %%
X = np.random.randn(10000, 64) + np.sin(np.linspace(0, 100, 10000)/1.)[:, np.newaxis] * 10

# %%
reload(resample)
Y = resample.resample(X, 50, 200)

# %%
plt.plot(X[:1000, 0])

# %%
plt.plot(Y[:250, 0])
